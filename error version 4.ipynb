# %%
class Queue:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []

    def enqueue(self, item):
        self.items.insert(0,item)

    def dequeue(self):
        if len(self.items) > 0 :
            return self.items.pop()
        else : 
            return ''

    def size(self):
        return len(self.items)
    
    def peek(self) :
        if len(self.items) > 0 :
            return self.items[0]

        else : 
            return '*'

    def peek1(self) :
        if len(self.items) > 1 :
            return self.items[1]

        else : 
            return '*'

# %%
import random

la = []

for i in range(60) :
    
    ll = []
    
    a = str(random.randint(1,2))
    b = str(random.randint(1,7))
    c = str(random.randint(1, 21))
    
    d = str(random.randint(1,7))
    e = str(random.randint(1, 21))
    
    while d == b and c == e :
        d = str(random.randint(1,7))
        e = str(random.randint(1, 21))
        
        
    if len(e) == 1 :
            e = '0' + e

    if len(c) == 1 :
        c = '0' + c

    cp = True
    
    while len(la) >0 :
        
        for j in range(len(la)) :
            
            if la[j][0] == a+b+c :
                cp = False
            
            if la[j][1] == a+b+c :
                cp = False
                
            if la[j][0] == a+d+e :
                cp = False
                
            if la[j][1] == a+d+e :
                cp = False
                
        break
    
    if cp :

        ll.append(a+b+c)
        ll.append(a+d+e)
        ll.append(Queue())

        la.append(ll)
    
la = la[0 : 50]
print(la)
# Out:
# [['2520', '2119', <__main__.Queue object at 0x012F44F0>], ['2302', '2618', <__main__.Queue object at 0x012F4550>], ['2208', '2512', <__main__.Queue object at 0x012F45B0>], ['2702', '2116', <__main__.Queue object at 0x012F4610>], ['1206', '1602', <__main__.Queue object at 0x012F4670>], ['1216', '1117', <__main__.Queue object at 0x012F46F0>], ['2719', '2411', <__main__.Queue object at 0x012F4750>], ['2508', '2504', <__main__.Queue object at 0x012F47B0>], ['1518', '1413', <__main__.Queue object at 0x012F4810>], ['2606', '2602', <__main__.Queue object at 0x012F4850>], ['2301', '2416', <__main__.Queue object at 0x012F48B0>], ['1705', '1502', <__main__.Queue object at 0x012F4910>], ['1219', '1616', <__main__.Queue object at 0x012F4970>], ['1312', '1515', <__main__.Queue object at 0x012F49D0>], ['2620', '2403', <__main__.Queue object at 0x012F4A30>], ['2210', '2205', <__main__.Queue object at 0x012F4A90>], ['1601', '1315', <__main__.Queue object at 0x012F4AF0>], ['1201', '1614', <__main__.Queue object at 0x012F4B50>], ['1109', '1718', <__main__.Queue object at 0x012F4BB0>], ['1221', '1114', <__main__.Queue object at 0x012F4C10>], ['2408', '2413', <__main__.Queue object at 0x012F4C70>], ['2206', '2604', <__main__.Queue object at 0x012F4CD0>], ['1704', '1204', <__main__.Queue object at 0x012F4D30>], ['1213', '1519', <__main__.Queue object at 0x012F4D90>], ['1506', '1514', <__main__.Queue object at 0x012F4DF0>], ['1106', '1703', <__main__.Queue object at 0x012F4E50>], ['1711', '1103', <__main__.Queue object at 0x012F4EB0>], ['1308', '1509', <__main__.Queue object at 0x012F4F10>], ['1606', '1210', <__main__.Queue object at 0x012F4F70>], ['1211', '1307', <__main__.Queue object at 0x012F4FD0>], ['2515', '2412', <__main__.Queue object at 0x01303050>], ['1412', '1517', <__main__.Queue object at 0x013030B0>], ['2201', '2707', <__main__.Queue object at 0x01303110>], ['1403', '1215', <__main__.Queue object at 0x01303170>], ['1317', '1107', <__main__.Queue object at 0x013031D0>], ['2714', '2108', <__main__.Queue object at 0x01303230>], ['1717', '1220', <__main__.Queue object at 0x01303290>], ['2103', '2506', <__main__.Queue object at 0x013032F0>], ['1314', '1608', <__main__.Queue object at 0x01303350>], ['2521', '2217', <__main__.Queue object at 0x013033B0>], ['2615', '2115', <__main__.Queue object at 0x01303410>], ['1313', '1116', <__main__.Queue object at 0x01303470>], ['1421', '1512', <__main__.Queue object at 0x013034D0>], ['1401', '1405', <__main__.Queue object at 0x01303530>]]

# %%
def chemf(k):

    a = Queue()
    b = Queue()
    dic = {}

    for i in k:
        a.enqueue(i)

    while not a.isEmpty():
        
        x = a.dequeue()
        
        if x == '(':
        
            t = a.dequeue()
            
            while True:
                
                b.enqueue(t)
                t = a.dequeue()
                
                if t == ')':
                    break
            
            m = ''
            
            while a.peek() in '1234567890':
                m += a.dequeue()
                m = int(m)
                
            while not b.isEmpty():
                
                w = b.dequeue()
                
                if b.peek() in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
                
                    if w in dic:
                        dic[w] = dic[w] + m
                        
                    else:
                        dic[w] = m

                elif b.peek() in '1234567890':
                    
                    q = ''
                    
                    while b.peek() in '1234567890':
                        q += b.dequeue()
                    
                    q = int(q)
                    
                    if w in dic:
                        dic[w] += q * m
                        
                    else:
                        dic[w] = q * m

                elif b.peek() == '*':
                    
                    if w in dic:
                        dic[w] = dic[w] + m
                        
                    else:
                        dic[w] = m

                else:
                    
                    l = b.dequeue()
                    u = w + l
                    
                    if b.peek() in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
                        
                        if u in dic:
                            dic[u] = dic[u] + m
                            
                        else:
                            dic[u] = m

                    elif b.peek() in '1234567890':
                        
                        y = ''
                        
                        while b.peek() in '1234567890':
                            y += b.dequeue()
                            
                        y = int(y)
                        
                        if x in dic:
                            dic[x] += y * m
                            
                        else:
                            dic[x] = y * m

                    else:
                        
                        if u in dic:
                            dic[u] = dic[u] + m
                            
                        else:
                            dic[u] = m

        else:
            
            if a.peek() in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
                
                if x in dic:
                    dic[x] = dic[x] + 1
                
                else:
                    dic[x] = 1

            elif a.peek() in '1234567890':
                
                y = ''
                
                while a.peek() in '1234567890':
                    y += a.dequeue()

                y = int(y)
                
                if x in dic:
                    dic[x] += y
                
                else:
                    dic[x] = y

            elif a.peek() == '*':
               
                if x in dic:
                    dic[x] = dic[x] + 1
                
                else:
                    dic[x] = 1

            elif a.peek() in 'abcdefghijklmnopqrstuvwxyz':
                
                e = a.dequeue()
                z = x + e

                if a.peek() in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
                
                    if z in dic:
                        dic[z] = dic[z] + 1

                    else:
                        dic[z] = 1

                elif a.peek() in '1234567890':
                    
                    y = ''
                    
                    while a.peek() in '1234567890':
                        y += a.dequeue()
                    
                    y = int(y)
                    
                    if z in dic:
                        dic[z] += y
                    
                    else:
                        dic[z] = y

                else:
                    
                    if z in dic:
                        dic[z] = dic[z] + 1
                    
                    else:
                        dic[z] = 1
    
    return dic

print(chemf('Na(NO3)2'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3e8f83c54710> in <module>()
#     172     return dic
#     173
# --> 174 print(chemf('Na(NO3)2'))
#
# <ipython-input-6-3e8f83c54710> in chemf(k)
#     118                     y += a.dequeue()
#     119
# --> 120                 y = int(y)
#     121
#     122                 if x in dic:
#
# ValueError: invalid literal for int() with base 10: 'a(NO3)2'
